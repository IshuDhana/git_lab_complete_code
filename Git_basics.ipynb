# %% [markdown]
# <a href="https://colab.research.google.com/github/IshuDhana/git_lab_complete_code/blob/main/Git_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# git install checking

# %%
git --version

# %% [markdown]
# install ubuntu

# %%
sudo apt git--install

# %% [markdown]
# Drag and drop the correct code to set your Git user name globally.

# %%
git config global user.name "Your Name"

# %% [markdown]
# Set your Git email to student@example.com

# %%
git config --global user.email "user@example.com"

# %% [markdown]
# Which command lists all your Git configuration settings?

# %%
git config --list

# %% [markdown]
# Drag and drop the correct command to change into your new project directory.

# %%
 cd myproject

# %% [markdown]
# Initialize Git on the current folder:

# %%
git init

# %% [markdown]
# What is a Git repository? A folder in git to track changes

# %% [markdown]
# Drag and drop the correct command to list files in your project directory.

# %%
ls index.html

# %% [markdown]
# Check the status of the Git:

# %%
git status

# %% [markdown]
# What does it mean if a file is untracked in Git? - Git does not know about this file yet.

# %% [markdown]
# What is the purpose of the staging area in Git? - To select which files will go to the commit.

# %% [markdown]
# Drag and drop the correct command to stage a file.

# %%
git add index.html

# %% [markdown]
# Stage all new, modified, and deleted files. Use the shorthand command:

# %%
git add -A

# %% [markdown]
# Drag and drop the correct flag to add a commit message.

# %%
git commit -m "Initial commit"

# %% [markdown]
# Commit the updated files directly, skipping the staging environment:

# %%
git commit -a -m "New line added"

# %% [markdown]
# What does a Git commit do? -  Takes a snapshot of the project with a message

# %% [markdown]
# View the history of commits for the repository: - git log

# %%
git log

# %% [markdown]
# GIT TAGGING

# %% [markdown]
# Drag and drop the correct flag to create an annotated tag with a message.

# %%
git tag -a v1.0 -m "Initial release"

# %% [markdown]
# Create an annotated tag named v2.0 with the message "Second release".

# %%
git tag -a v2.0 -m "Second release"

# %%
What is the main purpose of a Git tag?

# %%
To mark important points or releases in the project history

# %% [markdown]
# GIT STASH

# %% [markdown]
# Drag and drop the correct command to apply and remove the most recent stash.

# %%
git stash pop

# %% [markdown]
# Fill in the command to list all stashes.

# %%
git stash list

# %% [markdown]
# What does git stash do? - Saves your uncommitted changes for later.

# %% [markdown]
# GIT HISTROY

# %% [markdown]
# Drag and drop the correct flag to show a summary of all commits.

# %%
git stat -oneline

# %% [markdown]
# Show the changes introduced in the most recent commit.

# %%
git show HEAD

# %% [markdown]
# Which command shows only commits from the last week?

# %%
git log --since="1 week ago"

# %% [markdown]
# GIT HELP : Drag and drop the correct flag to show help for the status command.

# %%
git help status

# %% [markdown]
# Show all git possible commands in command line:

# %%
git help --all

# %% [markdown]
# Which command shows a quick summary of options for git commit?

# %%
git commit -h

# %% [markdown]
# GIT BRANCH

# %% [markdown]
# Which command switches to an existing branch?

# %%
git checkout branch-name

# %% [markdown]
# Drag and drop the correct command to create a new branch called hello-world-images.

# %%
git branch hello-world-images

# %% [markdown]
# List the existing branches:

# %%
git branch

# %% [markdown]
# GIT BRANCH MERGE

# %% [markdown]
# Drag and drop the correct command to merge the hello-you branch into the current branch.

# %%
git merge hello-you

# %% [markdown]
# Remove the hello-you branch from the local repository:

# %%
git branch -d hello-you

# %% [markdown]
# Which command aborts a merge in progress?

# %%
git merge --abort

# %% [markdown]
# What does a merge conflict mean? - There are incompatible changes in both branches that must be resolved manually.

# %% [markdown]
# GIT WORKFLOW

# %% [markdown]
# Drag and drop the correct command to move changes from the working directory to the staging area.

# %%
git add .

# %% [markdown]
# Which area in Git holds changes before they are committed? - Staging Area (Index)

# %% [markdown]
# What command saves staged changes to your local repository? - git commit

# %% [markdown]
# Which command shows the current status of files in your working directory and staging area? - git status

# %% [markdown]
# GIT PRACTICE EXERCISE

# %% [markdown]
# Drag and drop the command to run before git push to avoid conflicts.- git pull

# %% [markdown]
# Why should you write clear commit messages? - To help you and your team understand the project history.

# %% [markdown]
# Which file should you use to prevent tracking of build artifacts, logs, and secrets? - .gitignore

# %% [markdown]
# GIT SSH SECURITY

# %% [markdown]
# Drag and drop the correct algorithm to generate a new SSH key pair.

# %%
 ssh-keygen -t rsa -b 4096 -C "your@email.com"

# %% [markdown]
# Which command adds your private SSH key to the SSH agent?

# %%
ssh-add ~/.ssh/id_rsa

# %% [markdown]
# What should you NEVER do with your private SSH key? - Share it with anyone

# %% [markdown]
# Which file do you add to your GitHub/Bitbucket/GitLab account for SSH access? - The public key (e.g., id_rsa.pub)

# %% [markdown]
# GIT SET REMOTE

# %% [markdown]
# Drag and drop the correct subcommand to add a new remote.

# %%
git remote add origin git@github.com:username/repo.git

# %% [markdown]
# How do you update the URL for an existing remote named 'origin'?

# %%
git remote set-url origin git@github.com:username/repo.git

# %% [markdown]
# Check if your SSH connection is set up: - ssh -T git@github.com

# %% [markdown]
# Git Pull from Remote

# %% [markdown]
# Which command downloads new data from a remote repository but does NOT change your working files or branches? - git fetch

# %%
pull is a combination of: - fetch and then merge

# %% [markdown]
# Drag and drop the correct remote name to pull changes from the default remote repository. - git pull origin

# %% [markdown]
# Update the current branch from its origin using a single command: - git pull origin

# %% [markdown]
# Git Push to Remote

# %% [markdown]
# Drag and drop the correct command to upload local commits to the remote repository. - git push origin

# %% [markdown]
# Which action is always required before you can push new changes to a remote repository? - Make and commit changes

# %% [markdown]
# Push all local tags to the remote repository: - git push --tags

# %% [markdown]
# Git Remote Branch

# %% [markdown]
# Drag and drop the correct command to switch to a branch called 'branch-name'. - git  branch-name

# %% [markdown]
# Delete a branch named feature from the remote origin: - git push origin --delete feature

# %% [markdown]
# Which command creates a new branch and switches to it? - git switch -c branch-name

# %% [markdown]
# How do you delete a branch named 'feature' locally? - git branch -d feature

# %% [markdown]
# Git Pull from Remote Branch

# %% [markdown]
# Which command lists all local and remote branches? - git branch -a

# %% [markdown]
# Drag and drop the correct command to switch to a remote branch after fetching or pulling. - git checkout branch-name

# %% [markdown]
# After switching to a new remote branch, which command updates it with the latest changes? - git pull

# %% [markdown]
# List only remote branches of the current Git. - git branch -r

# %% [markdown]
# Git Push to Remote Branch

# %% [markdown]
# Which command will push your current branch to the remote named 'origin'?

# %%
git push origin

# %% [markdown]
# Write the command to push a branch named feature to the remote origin:

# %%
git push origin feature

# %% [markdown]
# Drag and drop the correct option to push all local branches to the remote 'origin'.

# %% [markdown]
# git push --all origin

# %% [markdown]
# Drag and drop the correct command to clone a repository to your computer.

# %%
git clone https://example.com/repo.git

# %% [markdown]
# Clone the repository https://abc.com/x/y.git to a folder named "newlife":

# %%
git clone https://abc.com/x/y.git newlife

# %% [markdown]
# What does the 'git clone' command do?

# %%
Copies a remote repository to your local machine

# %% [markdown]
# Drag and drop the correct remote name to push the branch 'feature' to your remote origin.

# %%
git push origin feature

# %% [markdown]
# Push your local changes to your remote origin:- git push origin

# %% [markdown]
# After pushing your changes to your fork, what is the next step to suggest your changes to the original repository? - Create a pull/merge request

# %% [markdown]
# GIT REVERT

# %% [markdown]
# Drag and drop the correct command to revert the latest commit. - git rivert HEAD

# %% [markdown]
# revert the latest commit, skipping the commit message editor: - git revert HEAD --no-edit

# %% [markdown]
# What does 'git revert' do? - Creates a new commit that undoes the changes of a previous commit.

# %% [markdown]
# GIT RESET

# %% [markdown]
# Drag and drop the correct option to reset to the commit with hash abc1234 and keep changes staged.

# %%
git reset --soft abc1234

# %% [markdown]
# reset to the commit with the hash abc1234: - git reset abc1234

# %% [markdown]
# What does 'git reset --hard' do? - Moves HEAD to a commit and deletes all changes in the working directory and index.

# %% [markdown]
# GIT AMEND

# %% [markdown]
# Drag and drop the correct option to amend the previous commit with a new message.

# %%
git commit --amend -m "Updated index"

# %% [markdown]
# What does 'git commit --amend' do? - Modifies the most recent commit, combining staged changes and/or changing the message.

# %% [markdown]
# GIT REBASE

# %% [markdown]
# Drag and drop the correct option to continue a rebase after resolving conflicts.

# %%
git rebase --continue

# %% [markdown]
# What is the correct code to abort a rebase in progress: - git rebase --abort

# %% [markdown]
# What does 'git rebase -i' do? - Starts an interactive rebase to edit, reorder, squash, or fix up commits.

# %% [markdown]
# GIT REFLOG

# %% [markdown]
# Drag and drop the correct option to show the log of reference updates (HEAD and branch changes). - git reflog

# %% [markdown]
# Restore the previous HEAD position using the reflog entry at index 2. - git reset --hard HEAD@{2}

# %% [markdown]
# What is the purpose of 'git reflog'? - To show the log of reference updates (HEAD and branch changes)

# %% [markdown]
# GIT RECOVERY

# %% [markdown]
# Drag and drop the correct option to show the reflog and recover lost commits. - git reflog

# %% [markdown]
# Restore a deleted branch from a commit hash - git checkout -b branch-name abc123

# %% [markdown]
# Which command can you use to recover a deleted or changed file from the latest commit? - git restore filename.txt

# %% [markdown]
# Restore the previous HEAD position using the reflog entry at index 2. - git reset --hard HEAD@{2}

# %% [markdown]
# GIT .GITIGNORE

# %% [markdown]
# Drag and drop the correct code to ignore all .log files in .gitignore. - *.log

# %% [markdown]
# In .gitignore add a line to ignore all files in any directory named temp: - temp/

# %% [markdown]
# Which pattern will ignore all files with the .tmp extension in .gitignore? - *.tmp

# %% [markdown]
# Git .gitattributes

# %% [markdown]
# Drag and drop the correct keyword to mark all PNG files as binary in .gitattributes. - *.png binary

# %% [markdown]
# How do you set all shell script files to use LF (Unix) line endings in .gitattributes? - *.sh text eol=lf

# %% [markdown]
# What is one common use for .gitattributes? - To set file handling rules like line endings, binary/text, or custom diff

# %% [markdown]
# Git LFS

# %% [markdown]
# Drag and drop the correct command to initialize Git LFS in your repository. - git lfs install

# %% [markdown]
# What command would you use to track all .zip files with Git LFS? - git lfs track "*.zip"

# %% [markdown]
# What does Git LFS do? - Stores pointers in your repo and large files on a separate server

# %% [markdown]
# Git Signing - git commit -S -m "message"

# %% [markdown]
# How do you sign a tag named v1.0 with a message using Git? - git tag -s v1.0 -m "version 1.0"

# %% [markdown]
# What is the main purpose of signing a Git commit? - To prove the commit was made by you and has not been tampered with

# %% [markdown]
# Git Cherry Pick/Patch

# %% [markdown]
# 1. Drag and drop the correct argument to add a line to the commit message showing where the commit came from. - git cherry-pick -x
#
# 2. How do you apply a patch file and keep the original author and message? - git am 0001-some-change.patch
#
# 3. What does git format-patch do? - Creates a patch file from one or more commits

# %% [markdown]
# Git Merge Conflicts

# %% [markdown]
# 1. Drag and drop the correct argument to keep only the other branch's changes during a conflict. - git checkout --theirs filename.txt
#
# 2. What command do you use to cancel an in-progress merge and return to the pre-merge state? - git merge --abort
#
# 3. Which command shows you which files have merge conflicts? - git status

# %% [markdown]
# Git CI/CD

# %% [markdown]
# 1. Drag and drop the correct event to trigger a CI/CD workflow on every code push. - on: [push]
#
# 2. What can you add to a commit message to skip running CI/CD for that commit? - git commit -m "Update docs [skip ci]"
#
# 3. Which file tells GitHub Actions how to run CI for your project? - .github/workflows/ci.yml

# %% [markdown]
# Git Hooks

# %% [markdown]
# 1. Drag and drop the correct command to search for "console.log" in all .js files in a pre-commit hook. - #!/bin/sh grep -r 'console.log' *.js
#
# 2. Where are Git hooks stored in your repository? - .git/hooks
#
# 3. Which hook runs before you make a commit and can be used to check code style? - pre-commit

# %% [markdown]
# Git Submodules

# %% [markdown]
# 1. Drag and drop the correct command to add a submodule to your project. - git submodule add https://github.com/example/library.git libs/library
#
# 2. After cloning a repo with submodules, what command fetches the submodule contents? - git submodule update
#
# 3. Which file keeps track of all submodules and their paths in your repository? - .gitmodules

# %% [markdown]
# Git Remote Advanced

# %% [markdown]
# 1. Drag and drop the correct command to add a new remote named upstream. - git remote add upstream https://github.com/w3schools/test.git
#
# 2. What command removes a remote named upstream? - git remote remove upstream
#
# 3. Which command lists all remotes and their URLs? - git remote -v
